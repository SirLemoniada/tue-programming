# %% [markdown]
# # JBI010 - Exercises Week 1 (2021-2022)
#
#
# ### Welcome to JBI010 Programming!
#
# This Jupyter notebook aims to provide exercises for practicing your programming skills.
#
# **Note:** Only five out of seven exercises–with a score of at least 80%–count for 5% of the course's final grade. Submit your notebook to Canvas, in this way Momotor will be able to give you feedback.

# %% [markdown]
# ## Table of Contents
# <div class="toc" style="margin-top: 1em;">
#     <ul class="toc-item">
#         <li>
#             <span><a href="#Introduction-to-this-template-notebook" data-toc-modified-id="Introduction-to-this-template-notebook">Introduction to this template notebook</a></span>
#         </li>
#         <li>
#             <span><a href="#Important-Reminder" data-toc-modified-id="Important-Reminder">Important Reminder</a></span>
#         </li>
#         <li>
#             <span><a href="#1.-Your-First-Program:-Hello-World!" data-toc-modified-id="1.-Your-First-Program:-Hello-World!">1. Your First Program: Hello World!</a></span>
#         </li>
#         <li>
#             <span><a href="#2.-Hello-World!-2.0" data-toc-modified-id="2.-Hello-World!-2.0">2. Hello World! 2.0</a></span>
#         </li>
#         <li>
#             <span><a href="#3.-format()-Method" data-toc-modified-id="3.-format()-Method">3. format() Method </a></span>
#         </li>
#         <li>
#             <span><a href="#4.-The-Answer-to-Time" data-toc-modified-id="4.-The-Answer-to-Time">4. The Answer to Time</a></span>
#         </li>
#         <li>
#             <span><a href="#5.-Kilometers-to-Miles" data-toc-modified-id="5.-Kilometers-to-Miles">5. Kilometers to Miles</a></span>
#         </li>
#         <li>
#             <span><a href="#6.-Truth-Table" data-toc-modified-id="6.-Truth-Table">6. Truth Table</a></span>
#         </li>
#         <li>
#             <span><a href="#7.-Finding-the-Largest" data-toc-modified-id="7.-Finding-the-Largest">7. Finding the Largest</a></span>
#         </li>
#         <li>
#             <span><a href="#8.-Sorting-Three-Numbers" data-toc-modified-id="8.-Sorting-Three-Numbers">8. Sorting Three Numbers</a></span>
#         </li>
#         <li>
#             <span><a href="#9.-Counting-Iterations" data-toc-modified-id="9.-Counting-Iterations">9. Counting Iterations</a></span>
#         </li>
#         <li>
#             <span><a href="#10.-Tick-Tock" data-toc-modified-id="10.-Tick-Tock">10. Tick Tock</a></span>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# # Introduction to this template notebook
#
# * This is a **personal** notebook.
# * Make sure you work in a **copy** of `...-template.ipynb`,
#     **renamed** to `...-yourIDnr.ipynb`,
#     where `yourIDnr` is your TU/e identification number.
# * In case of two authors, include both id. numbers:
#     `...-firstIDnr-secondIDnr.ipynb`.
#
# <div class="alert alert-danger" role="danger">
# <h3>Integrity</h3>
# <ul>
#     <li>In this course you must act according to the rules of the TU/e code of scientific conduct.</li>
#     <li>All the exercises and the graded assignments are to be done within your programming homework group.</li>
#     <li>You must not copy from the Internet, your friends, books... If you represent other people's work as your own, then that constitutes fraud and will be reported to the Examination Committee.</li>
#     <li>Making your work available to others (complicity) also constitutes fraud.</li>
# </ul>
# </div>
#
# You are expected to work with Python 3 code in this notebook.
#
# The locations where you should write your solutions can be recognized by
# **marker lines**,
# which look like this:
#
# >`#//`
# >    `BEGIN_TODO [Label]` `Description` `(n points)`
# >
# >`#//`
# >    `END_TODO [Label]`
#
# <div class="alert alert-warning" role="alert">Do NOT modify or delete these marker lines.  Keep them as they are.<br/>
# <br/>
# NEVER write code that is needed for grading <i>outside</i> the marked blocks.
# It is invisible there.
# </div>
#
# Proceed in this notebook as follows:
# * **Personalize** the notebook (see below)
# * **Read** the text.
# * **Fill in** your solutions between `BEGIN_TODO` and `END_TODO` marker lines.
# * **Run** _all_ code cells (also the ones _without_ your code),
#     _in linear order_ from the first code cell.
#
# **Personalize your notebook**:
# 1. Copy the following lines of code (`AUTHOR2_...` only when applicable):
#
#   ```python
#   AUTHOR_NAME = 'Your Full Name'
#   AUTHOR_ID_NR = '1234567'
#   AUTHOR_DATE = 'YYYY-MM-DD'  # when first modified, e.g. '2019-02-26'
#
#   AUTHOR2_NAME = 'Not Applicable'
#   AUTHOR2_ID_NR = 'Not Applicable'
#   ```
#
# 1. Paste them between the marker lines in the next code cell.
# 1. Fill in your _full name_, _identification number_, and the current _date_ as strings between quotes.
# 1. When applicable, also copy and fill in the name and id.nr. for the second author.
# 1. Run the code cell by putting the cursor there and typing **Control-Enter**.

# %%
#// BEGIN_TODO [Author] Name, Id.nr., Date, as strings (1 point)

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [Author]

AUTHOR_NAME, AUTHOR_ID_NR, AUTHOR_DATE

# %% [markdown]
# ## Preliminaries
#
# Run the cell below. This cell will import additional modules providing additional Python functionality.

# %%
# This set of exercises does not need additional modules

# %% [markdown]
# ## Important Reminder
#
# * Follow all coding conventions defined on the Python Coding Standard document available via Canvas. Remember that you are not just programming for a **machine**, you are mainly programming for **other humans!**
#     * In particular, all function definitions must have **type hints** and a **docstring**.
#     * A *valid* **docstring** starts with a capital letter and ends with a dot.

# %% [markdown]
# ## 1. Your First Program: Hello World!
#
# The first thing to do when starting to learn any programming language is to make a program that prints the message: **Hello world!**. This starting program is often very small and only uses some basic functionality of the programming language.
#
# Now, as your first experience with Python, write code using the `print()` function. The program, as expected, should print the message: 'Hello world!'. The quotes should not be in the output. They are used in the description of the exercises to indicate strings.
#
# **Notes:**
# - Remember that with Python you can either use single (`''`) or double quotes (`""`) to create strings.
# - Beware that capital and lowercase letters are treated different in Python. That is, 'L' is differently from 'l'.
#
# **Example:**
# *Input:*
# <pre>
# None
# </pre>
#
# *Output:*
# <pre>
# Hello world!
# </pre>

# %%
#// BEGIN_TODO [hello_world] Your first program: Hello world!

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [hello_world]

# %% [markdown]
# **Congratulations on your first Python program!**<br>
# Many more will surely follow!

# %% [markdown]
# ## 2. Hello World! 2.0

# %% [markdown]
# Printing messages as strings is a good way to output information on the screen, so you or others can read it. Usually, we want to output the **values** stored in **variables** together with the message.
#
# Create a program that prints a message, using the `AUTHOR_NAME` and `AUTHOR_ID_NR` variables that you created at the start of the notebook. The message should be as follows: 'Hello World! My name is `AUTHOR_NAME` and my ID is `AUTHOR_ID_NR`.' The quotes should not be in the output. They are used in the description of the exercises to indicate strings.
#
# **Notes**:
# - You do not need to redefine the `AUTHOR_NAME` and `AUTHOR_ID_NR` variables.
# - You are not allowed to use the `.format()` method.
# - Beware of upper and lowercase letters, as well of extra characters that have (not) been requested in the exercise (e.g. final '.' at the end of the message).
#
# **Example:**
# *Input:*
# ```python
# AUTHOR_NAME = 'Your name'
# AUTHOR_ID_NR = 'Your ID number'
# ```
#
# *Output:*
# <pre>
# Hello World! My name is [AUTHOR_NAME] and my ID is [AUTHOR_ID_NR].
# </pre>

# %%
#// BEGIN_TODO [hello_world_2.0] Hello world! 2.0

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [hello_world_2.0]

# %% [markdown]
# ## 3. format() Method
#
# Print the same message as the one in the exercise above, but this time use the `format()` method to use the variables in the string.
#
# **Example:**
# *Input:*
# ```python
# AUTHOR_NAME = 'Your name'
# AUTHOR_ID_NR = 'Your ID number'
# ```
#
# *Output:*
# <pre>
# Hello World! My name is [AUTHOR_NAME] and my ID is [AUTHOR_ID_NR].
# </pre>

# %%
#// BEGIN_TODO [format_method] format() method

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [format_method]

# %% [markdown]
# ## 4. The Answer to Time
# Computers tend to be much faster in solving equations than we, humans, are. However, to do so, humans have to specify the equations, so computers are able to solve them. Write a program that calculates how many seconds there are in 42 minutes and 42 seconds. Assign the answer to the variable `time` and then print its value.
#
# **Note:** Do not modify the format of the resulting number. (Any change in the format might result in a failing test.)
#
# **Example:**
# *Input:*
# <pre>
# None
# </pre>
#
# *Output:*
# <pre>
# 2562
# </pre>

# %%
#// BEGIN_TODO [answer_to_time] The answer to time

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [answer_to_time]

# %% [markdown]
# ## 5. Kilometers to Miles
#
# Write a program that calculates how many miles there are in 10 kilometers (we are using the variable `kilometers` to store this value). Assign the answer to the variable `miles` and print the result.
#
# **Hint:** There are 1.61 kilometers in a mile.
#
# **Example:**
# *Input:*
# ```python
# kilometers = 10
# ```
#
# *Output:*
# <pre>
# 6.211180124223602
# </pre>

# %%
kilometers = 10

#// BEGIN_TODO [kms_to_miles] Kilometers to miles

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [kms_to_miles]

# %% [markdown]
# ## 6. Truth Table
#
# A truth table is a mathematical artifact that defines the value of a logical expression given a set of logical arguments. Consider the truth table below: `bool1`, `bool2`, and `bool3` are the logical variables of the expression. In this table, we display a subset of all possible outputs. You need to know that there is only one case where the output of the expression evaluates to `True`: when `bool1` equals `False`, `bool2` equals `True`, and `bool3` equals `False`. All other cases evaluate to `False`. Compute the expected output given the values assigned to the `bool1`, `bool2`, and `bool3` variables. Store the result in the `output` variable and print its value.
#
# <table>
#     <tr>
#         <th>bool1</th>
#         <th>bool2</th>
#         <th>bool3</th>
#         <th>Output</th>
#     </tr>
#     <tr>
#         <td>True</td>
#         <td>True</td>
#         <td>True</td>
#         <td>False</td>
#     </tr>
#     <tr>
#         <td>False</td>
#         <td>True</td>
#         <td>False</td>
#         <td>True</td>
#     </tr>
#     <tr>
#         <td>False</td>
#         <td>False</td>
#         <td>False</td>
#         <td>False</td>
#     </tr>
#     <tr>
#         <td>...</td>
#         <td>...</td>
#         <td>...</td>
#         <td>...</td>
#     </tr>
# </table>
#
# **Example:**
# *Input:*
# ```python
# bool1 = True
# bool2 = True
# bool3 = False
# ```
#
# *Output:*
# <pre>
# False
# </pre>

# %%
bool1 = True
bool2 = True
bool3 = False

#// BEGIN_TODO [truth_table] Truth table

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [truth_table]

# %% [markdown]
# ## 7. Finding the Largest
#
# Given two numbers `number_1` and `number_2`, print a message indicating which one is the largest. That is,
# - if `number_1` is larger print: 'Number 1, `number_1`, is the biggest number!';
# - if `number_2` is larger print: 'Number 2, `number_2`, is the biggest number!';
# - else, if both numbers are equal print the message: 'Both numbers are equal!'
#
# **Note:** Your code should work with any two numbers.
#
# **Example:**
#
# *Input:*
# ```python
# number_1 = 120
# number_2 = 95
# ```
#
# *Output:*
# <pre>
# Number 1, 120, is the biggest number!
# </pre>

# %%
number_1 = 120
number_2 = 95

#// BEGIN_TODO [finding_largest] Finding the largest

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [finding_largest]

# %% [markdown]
# ## 8. Sorting Three Numbers
#
# Considering that we have three numbers, `number_1`, `number_2`, and `number_3`, write a program to sort these numbers such that `number_1` has the largest value and `number_3` the smallest.
#
# **Note:** Use conditionals to solve this problem.
#
# **Example:**
#
# *Input:*
# ```python
# number_1 = 56
# number_2 = 24
# number_3 = 100
# ```
#
# *Output:*
# ```python
# number_1 = 100
# number_2 = 56
# number_3 = 24
# ```

# %%
number_1 = 56
number_2 = 24
number_3 = 100

#// BEGIN_TODO [sorting_3_numbers] Sorting three numbers

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [sorting_3_numbers]

print(number_1, number_2, number_3)

# %% [markdown]
# ## 9. Counting Iterations
#
# We want to track the number of iterations that a `while`-loop does. To do so, create a `while`-loop that prints the number of iterations it has already done. You should start printing from 0 because in its first iteration the loop hasn't done any iterations yet. The variable `MAX_NUMBER_OF_LOOPS` defines the total number of iterations that the `while`-loop should make.
#
# **Note:** Do not alter the value of the `MAX_NUMBER_OF_LOOPS`.
#
# **Example:**
#
# *Input:*
# ```python
# MAX_NUMBER_OF_LOOPS = 2
# ```
#
# *Output:*
# <pre>
# 0
# 1
# 2
# </pre>

# %%
MAX_NUMBER_OF_LOOPS = 20

#// BEGIN_TODO [counting_iterations] Counting iterations

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [counting_iterations]

# %% [markdown]
# ## 10. Tick Tock
# Create a timer that, once started, prints the minutes and seconds that have passed. The timer should stop once the time, given by the `minutes` and `seconds` variables, has passed. Use the same format to print messages for a different number of *minutes* and *seconds*.
#
# **Notes:**
# - For this exercise, you will be using the `time` module (no action is required from your side).
# - Assume that the execution of the loop takes 0 seconds.
#
# **Hints:**
# - The `time.sleep(x)` expression will halt your program for `x` seconds.
# - To understand `time.sleep(x)`, run the program written in the following cell.
#
# **Example:**
#
# *Input:*
# ```python
# minutes = 0
# seconds = 5
# ```
#
# *Output:*
# <pre>
# 0 minutes and 1 seconds have past
# 0 minutes and 2 seconds have past
# 0 minutes and 3 seconds have past
# 0 minutes and 4 seconds have past
# 0 minutes and 5 seconds have past
# </pre>

# %%
import time

pause = 2

print("The")
time.sleep(pause)

print("weather")
time.sleep(pause)

print("is")
time.sleep(pause)

print("nice")

# %%
import time

seconds = 5
minutes = 0

#// BEGIN_TODO [tick_tock] Tick tock

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [tick_tock]

# %%
# %whos

# %% [markdown]
# ---
#
# ## (End of Notebook)
#
# &copy; 2017-2021 - **TU/e** - Eindhoven University of Technology
