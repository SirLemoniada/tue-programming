# %% [markdown]
# # JBI010 - Exercises Week 2 (2021-2022)
#
# This Jupyter notebook aims to provide exercises for practicing your programming skills.
#
# **Note:** Only five out of seven exercises–with a score of at least 80%–count for 5% of the course's final grade. Submit your notebook to Canvas, in this way Momotor will be able to give you feedback.

# %% [markdown]
# ## Table of Contents
# <div class="toc" style="margin-top: 1em;">
#     <ul class="toc-item">
#         <li>
#             <span><a href="#Introduction-to-this-template-notebook" data-toc-modified-id="Introduction-to-this-template-notebook">Introduction to this template notebook</a></span>
#         </li>
#         <li>
#             <span><a href="#Important-Reminder" data-toc-modified-id="Important-Reminder">Important Reminder</a></span>
#         </li>
#         <li>
#             <span><a href="#1.-Hip-Hip,-Hooray" data-toc-modified-id="1.-Hip-Hip,-Hooray">1. Hip Hip, Hooray</a></span>
#         </li>
#         <li>
#             <span><a href="#2.-Prime-Search" data-toc-modified-id="2.-Prime-Search">2. Prime Search</a></span>
#         </li>
#         <li>
#             <span><a href="#3.-Collatz-Problem" data-toc-modified-id="3.-Collatz-Problem">3. Collatz Problem</a></span>
#         </li>
#         <li>
#             <span><a href="#4.-gnitirW-sdrawkcaB" data-toc-modified-id="4.-gnitirW-sdrawkcaB">4. gnitirW sdrawkcaB</a></span>
#         </li>
#         <li>
#             <span><a href="#5.-Writing-Books" data-toc-modified-id="5.-Writing-Books">5. Writing Books</a></span>
#         </li>
#         <li>
#             <span><a href="#6.-Insurance-Calculations" data-toc-modified-id="6.-Insurance-Calculations">6. Insurance Calculations</a></span>
#         </li>
#         <li>
#             <span><a href="#7.-Sorting" data-toc-modified-id="7.-Sorting">7. Sorting</a></span>
#         </li>
#         <li>
#             <span><a href="#8.-Multi-Multiplication<" data-toc-modified-id="8.-Multi-Multiplication<">8. Multi Multiplication</a></span>
#         </li>
#         <li>
#             <span><a href="#9.-String-Cleaning" data-toc-modified-id="9.-String-Cleaning">9. String Cleaning</a></span>
#         </li>
#         <li>
#             <span><a href="#10.-Counting-Letters" data-toc-modified-id="10.-Counting-Letters">10. Counting Letters</a></span>
#         </li>
#     </ul>
# </div>

# %%
#// BEGIN_TODO [Author] Name, Id.nr., Date, as strings (1 point)

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [Author]

AUTHOR_NAME, AUTHOR_ID_NR, AUTHOR_DATE

# %% [markdown]
# ## Preliminaries
#
# Run the cell below. This cell will import additional modules providing additional Python functionality.

# %%
# This set of exercises does not need additional modules

# %% [markdown]
# ## Important Reminder
#
# * Follow all coding conventions defined on the Python Coding Standard document available via Canvas. Remember that you are not just programming for a **machine**, you are mainly programming for **other humans!**
#     * In particular, all function definitions must have **type hints** and a **docstring**.
#     * A *valid* **docstring** starts with a capital letter and ends with a dot.

# %% [markdown]
# ## 1. Hip Hip, Hooray
#
# It's your professors birthday!<br>
# To celebrate create a program that prints the message, **Hip Hip, Hooray**, as many times as his new age.
# Define a variable called `new_age` to store the new age.
# Print **Hip Hip, Hooray** inside a `while-`loop.
#
# **Example:**
# *Input:*
# ```python
# new_age = 3
# ```
#
# *Output:*
# <pre>
# Hip Hip, Hooray
# Hip Hip, Hooray
# Hip Hip, Hooray
# </pre>

# %%
new_age = 3

#// BEGIN_TODO [birthday] Hip Hip, Hooray (1 point)

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [birthday]

# %% [markdown]
# ## 2. Prime Search
#
# *Prime* numbers are integers that can only be divided by 1 and itself.<br>
# For instance, 2, 3, and 5 are *prime* numbers, but 4, 6, and 10 are not.
# A simple, yet not effective, way to discover works like this:
# * Select a candidate number
# * Check if such number is divisible between another number smaller than itself
# * If there is no such divider, the number is prime
#
# For this exercise create a program that prints all prime numbers from 2 up to 100. Number (2) is chosen because it is the beginning of the *prime* numbers set.
#
# **Note:** Your code should work with any two numbers.
#
# **Hint:** consider using nested `while`-loops and `break` to solve this problem.
#
# **Example:**
# *Input:*
# ```python
# i = 2
# ```
#
# *Output:*
# <pre>
# 2 is prime
# 3 is prime
# 5 is prime
# 7 is prime
#     .
#     .
#     .
# </pre>

# %%
i = 2

#// BEGIN_TODO [primes] Prime Search (1 point)

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [primes]

# %% [markdown]
# ## 3. Collatz Problem
#
# We can use `while`-loops to test mathematical problems such as the *Collatz* problem.<br>
# The *Collatz* problem is an easy iterated formula in which you have an *integer* variable called `integer` and has the following formula:
# * If the `integer` is even: Divide the integer by 2
# * If the `integer` is odd: Multiply the integer by 3 and add 1
# * Do this until the sequence reaches 1 (After which it will loop 1, 4, 2, 1, ...)
#
# **Note:** The question of the *Collatz* problem is whether every starting value will eventually reach 1.
# This has not been formally proven yet, but it is assumed to be true.
#
# **Hint:** You need to create a program using a `while`-loop that prints the *Collatz* sequence of an *integer*.
#
# **Example:**
# *Input:*
# ```python
# integer = 20
# ```
#
# *Output:*
# <pre>
# 10
# 5
# 16
# 8
# 4
# 2
# 1
# </pre>

# %%
integer = 20

#// BEGIN_TODO [Collatz] Collatz Problem (1 point)

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [Collatz]

# %% [markdown]
# ## 4. gnitirW sdrawkcaB
#
# We can use `while`-loops in a function to reverse a string.
#
# For this exercise create a function called `print_backwards` that uses the *string* variable `word` and prints the letters backward, one letter per line.
#
# **Hints:**
# - This function will only print, it does not return anything.
# - Use `len(word)` to determine the string's length.
# - Use `word[i]` to take the letter at index i.
# - Keep in mind that the first character is at index 0.
# - Use `print(..., end='')` to suppress printing a new line.
#
# **Example:**
# *Input:*
# ```python
# word = 'Pizza!'
# ```
#
# *Output:*
# <pre>
# !azziP
# </pre>

# %%
#// BEGIN_TODO [reversed] gnitirW sdrawkcaB (1 point)

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [reversed]

word = 'Data Science'
print_backwards(word)

# %% [markdown]
# ## 5. Writing Books
#
# We would like to print all chapters and sections for a book.<br>
#
# For this exercise create a function called `print_chapters`, which has `start_chapter`, `final_chapter`, and `max_section` as *integer* parameters:
#
# * `start_chapter` is the first chapter you are going to print.
# * `final_chapter` is the final chapter you are going to print.
# * `max_section` is the number of sections each chapter has - All chapters have the same number of `max-section`.
#
# **Hint:** `print_chapters` has to print all chapters and sections within each chapter.
#
# **Example:**
# *Input:*
# ```python
# start_chapter = 1
# final_chapter = 3
# max_section = 2
# ```
#
# *Output:*
# <pre>
# Chapter 1
# Section 1.1
# Section 1.2
# Chapter 2
# Section 2.1
# Section 2.2
# Chapter 3
# Section 3.1
# Section 3.2
# </pre>

# %%
#// BEGIN_TODO [books] Writing Books (1 point)

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [books]

print_chapters(1, 4, 2)

# %% [markdown]
# ## 6. Insurance Calculations
#
# We would like to check what price someones car insurance will be.<br>
# This is based on the total amount of light and heavy accidents that the person made over the last year, and the number of years of driving experience.
#
# For this exercise, we need to create a function that checks the price as often as we want, because we need to check it for multiple people.
#
# We have already made a skeleton of the function called `checkPrice` (so there is no code within the function), your job is to finish the function such that:
# * The base insurance is 2,000 a year
# * Every light accident increases the price by 100
# * Every heavy accident increases the total price by 10%
# * Every year of driving experience drops the price by 200, but only after the first 5 learner years.
# * The price of the insurance can never be lower than 800
#
# **Hint:** `checkPrice` has to return the price of the insurance.
#
# **Example:**
# *Input:*
# ```python
# light_accidents = 0
# heavy_accidents = 0
# driving_experience = 0
# ```
#
# *Output:*
# <pre>
# 2000.0
# </pre>

# %%
def checkPrice(light_accidents: int, 
               heavy_accidents: int, 
               driving_experience: int) -> float:
    
    #// BEGIN_TODO [insurance] Insurance Calculations (1 point)

# ===== =====> Replace this line by your code. <===== ===== #

    #// END_TODO [insurance]

# Check the price for someone who started driving a year ago
print(checkPrice(1, 0, 1))

# Price for someone who has been driving for 10 years with a few accidents
print(checkPrice(10, 3, 10))

# %% [markdown]
# ## 7. Sorting
#
# For this exercise create a function called `sorting`, which takes three *integers* as arguments.<br>
# This function should sort in ascending order and return the numbers in a string. Numbers should be separated by *commas*, and one *space* is required after each *comma*.
#
# **Note:**
# - This function returns something and does not print.
#
# **Hint:**
# - Use `max` and `min` functions instead of using `if`-statements to solve this problem.
#
# **Example:**
# *Input:*
# ```python
# num1 = 4
# num2 = 7
# num3 = 2
# ```
#
# *Output:*
# <pre>
# 2, 4, 7
# </pre>

# %%
#// BEGIN_TODO [sorting_numbers] Sorting (1 point)

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [sorting_numbers]

print(sorting(17, 5, 9))

# %% [markdown]
# ## 8. Multi Multiplication
#
# Functions can have all possible variable types as parameters.<br>
# This includes *integers*, *floats*, and *strings*. <br>
# But functions can also take other functions as parameters.<br>
# In order to test this, we are going to create two functions for this exercise:
# * The first function called `multiply`, which multiplies the two arguments acalled `number_1` and `number_2` and then returns the result.
# * The second function called `run_triple`, which it will take the function `multiply` as an argument, and will be able to call it twice, using different values. `run_triple` should also multiply these two values again and return the final result.
#
# **Hint:** The type to use for functions as arguments is 'callable'.
#
#
# **Example:**
# *Input:*
# ```python
# function multiply
# num1 = 2
# num2 = 3
# num3 = 3
# num4 = 4
# ```
#
# *Output:*
# <pre>
# 72
# </pre>

# %%
#// BEGIN_TODO [run_triple] Multi Multiplication (1 point)

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [run_triple]

print(run_triple(multiply, 2, 5, 3, 7))

# %% [markdown]
# ## 9. String Cleaning
#
# Your database is storing the names of customers.<br>
# However, because of the way we use these names, the stored names have to follow certain rules.
#
# For this exercise create a function called `standardize_name` that changes the name if it does not comply to the rules, into names that do.
# Return the changed name, or the original name when it does follow the naming rules.
#
# The rules for the names are:
# * Start with capital letter
# * All other letters are lowercase
# * Only the characters a-z A-Z are allowed in the name, any other letters have to be deleted
# * Spaces and tabs are not allowed, underscores are used instead
# * Names can be no longer than 80 characters, longer names will lose their extra letters
#
# **Example:**
# *Input:*
# ```python
# name = "python3 cOUrse"
# ```
#
# *Output:*
# <pre>
# Python_course
# </pre>

# %%
#// BEGIN_TODO [transforming_names] String Cleaning (1 point)

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [transforming_names]

name = "Anna2 fRank"
print(standardize_name(name))

name = "_anna2 fRank_" 
print(standardize_name(name))

name = "JhonnieWalker- DrinksTequila InGasselterboerveenschemond"
print(standardize_name(name))

# %% [markdown]
# ## 10. Counting Letters
#
# For this exercise create a function called `count_case` that accepts a *string* and returns the number of upper and lower case letters as a string.
#
# **Example:**
# *Input:*
# ```python
# "I am currently attending Programing Course"
# ```
#
# *Output:*
# <pre>
# Upper case: 3 - Lower case: 34
# </pre>

# %%
#// BEGIN_TODO [count_case] Counting Letters (1 point)

# ===== =====> Replace this line by your code. <===== ===== #

#// END_TODO [count_case]

print(count_case("I am Currently Working on this"))

# %% [markdown]
# ## How to submit your work
#
# 1. **Before submitting**, you must run your notebook by doing **Kernel > Restart & Run All**.
#    Make sure that your notebook runs without errors **in linear order**.
#
# 2. Remember to rename the notebook, replacing `...-template.ipynb` with `...-yourIDnr.ipynb`, where `yourIDnr` is your TU/e identification number.
#
# 3. Submit the executed notebook with your work
#    for the appropriate assignment in **Canvas**.
#
# * In the **Momotor** tab in Canvas,
#   you can select that assignment again to find some feedback on your submitted work.
#
# * If there are any problems reported by _Momotor_,
#   then you need to fix those,
#   and **resubmit the fixed notebook**.
#
# In case of a high workload on our server
# (because many students submit close to the deadline),
# it may take longer to receive the feedback.

# %%
# %whos

# %% [markdown]
# ---
#
# ## (End of Notebook)
#
# &copy; 2017-2021 - **TU/e** - Eindhoven University of Technology
